# %%
pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (2.0.29)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (8.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy as db

# %%
"motorDB://usuario:contraseña@ipservidor:3306/nombreDB"
# Out:
# 'motorDB://usuario:contraseña@ipservidor:3306/nombreDB'

# %%
class ConexionMySQL():
    def __init__(self, db_servidor, db_nombre, db_usuario, db_contrasenia):
        self.db_servidor = db_servidor
        self.db_nombre = db_nombre
        self.db_usuario = db_usuario
        self.db_contrasenia = db_contrasenia
    
    def conectarMySQL(self):
        engine = db.create_engine(f"mysql+mysqlconnector://{self.db_usuario}:{self.db_contrasenia}@{self.db_servidor}:3306/{self.db_nombre}")

        conn = engine.connect()
        return conn

# %%
# DB Academico Datapath
obj_academico = ConexionMySQL(
    "localhost",
    "academy_datapath",
    "root",
    "123456"
    
)

conn_academico = obj_academico.conectarMySQL()

# %%
import pandas as pd

# %%
query_cliente = "SELECT * FROM estudiante"

# %%
cliente = pd.read_sql(query_cliente, con=conn_academico)

# %%
cliente_data = cliente[["dni_estudiante","nombre","domicilio"]]

# %%
cliente_data.head()
# Out:
#   dni_estudiante                          nombre  \
# 0       23423442        Kenyo Harold Cano Campos
# 1       23423525  Jeisser Augusto Asto Sifuentes
# 2       34534573      Christian Caballero Mueras
# 3       34534576          Elayne Palacios Vargas
# 4       34534634                  Esteban Vargas
#
#                                            domicilio
# 0               Jr 28 De Julio 537 A Cercado - Surco
# 1                        Av Puente piedra 543 - Lima
# 2  Av Independencia Cda 06 Ex Casa Campesin - La ...
# 3                           av Perú 114 - Los olivos
# 4                          Jr. Ucayali N° 388  - SJL

# %%
query_programa = "select codigo_programa,descripcion,inversion from programa"

# %%
programa_data = pd.read_sql(query_programa, con=conn_academico)

# %%
programa_data
# Out:
#    codigo_programa                        descripcion  inversion
# 0                1     Data Analyst Program I Edición      600.0
# 1                2    Data Analyst Program II Edición      700.0
# 2                3   Data Analyst Program III Edición      550.0
# 3                4    Data Engineer Program I Edición      800.0
# 4                5   Data Engineer Program II Edición      450.0
# 5                6   Data Scientist Program I Edición      850.0
# 6                7  Data Scientist Program II Edición      650.0

# %%
matricula_data = pd.read_sql("select codigo_programa, dni_estudiante, fecha_matricula from programa_estudiante", con=conn_academico)

# %%
matricula_data
# Out:
#    codigo_programa dni_estudiante fecha_matricula
# 0                1       23423442      2023-01-01
# 1                2       23423525      2023-01-04
# 2                3       34534573      2023-01-10
# 3                4       34534576      2023-01-11
# 4                5       34534634      2023-01-20
# 5                6       34634636      2023-03-02
# 6                7       34636567      2023-03-02
# 7                6       45645647      2023-03-12
# 8                5       45646647      2023-03-25
# 9                7       65756756      2023-02-23

# %%
# DB Academico Datapath
obj_academico = ConexionMySQL(
    "localhost",
    "dbventas_datapath",
    "root",
    "123456"
    
)

conn_ventas = obj_academico.conectarMySQL()

# %%
vendedor_data=pd.read_sql('select * from vendedor', con=conn_ventas)
vendedor_data
# Out:
#    idvendedor            nombre sexo                            dirección
# 0           1    Fredy Saavedra    M              AV la merced - Colombia
# 1           2    Maria Cisneros    F               jr manco capac 118 SJM
# 2           3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú

# %%
ventas_data=pd.read_sql('SELECT idEstudiante,idPrograma,idVendedor,montofinalventa FROM ventas_programa', con=conn_ventas)
ventas_data
# Out:
#    idEstudiante  idPrograma  idVendedor  montofinalventa
# 0      23423442           1           1            450.0
# 1      23423525           2           2            350.0
# 2      34534573           3           3            550.0
# 3      34534576           4           3            599.0
# 4      34534634           5           2            300.0
# 5      34634636           6           1            800.0
# 6      34636567           7           1            500.0
# 7      45645647           6           3            700.0
# 8      45646647           5           2            300.0
# 9      45647836           3           1            450.0
# 10     76565434           1           2            430.0
# 11     56756776           2           3            350.0
# 12     65756756           5           1            300.0

# %%
df_mkt = pd.read_csv("social_media_income.csv")
df_mkt.head()
# Out:
#   idCampaña                    nombrePrograma  dniEstudiante plataforma  \
# 0   001DAP1    Data Analyst Program I Edición       23423442   Facebook
# 1   002DAP2   Data Analyst Program II Edición       23423525     Tiktok
# 2   003DAP3  Data Analyst Program III Edición       34534573  Instagram
# 3   001DEP1   Data Engineer Program I Edición       34534576  Instagram
# 4   001DEP2  Data Engineer Program II Edición       34534634     Tiktok
#
#   communityManager costoUSD
# 0    Flavia Avanto    0.972
# 1      Naomi Colan     2.34
# 2    Flavia Avanto    1.542
# 3    Flavia Avanto  1.6234s
# 4    Flavia Avanto   2.5246

# %% [markdown]
# #Webscrapping

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from requests) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (5.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.infodolar.com.pe/")

# %%
page.content
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <!-- Google Tag Manager -->\r\n    <script>(function (w, d, s, l, i) {\r\n            w[l] = w[l] || []; w[l].push({\r\n                \'gtm.start\':\r\n                    new Date().getTime(), event: \'gtm.js\'\r\n            }); var f = d.getElementsByTagName(s)[0],\r\n                j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\'; j.async = true; j.src =\r\n                    \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl; f.parentNode.insertBefore(j, f);\r\n        })(window, document, \'script\', \'dataLayer\', \'GTM-5FMGPWS\');</script>\r\n    <!-- End Google Tag Manager -->\r\n    <title>\r\n\tPrecio del d\xc3\xb3lar - InfoDolar.com.pe\r\n</title>\r\n    <meta name="Description" content="Precio del d\xc3\xb3lar hoy en Per\xc3\xba de cada banco y casa de cambio al instante. Tipo de cambio en Per\xc3\xba" />\r\n    <meta name="keywords" content="d\xc3\xb3lar, dolar, precio dolar, precio d\xc3\xb3lar, precio dolar Peru, d\xc3\xb3lar paralelo, d\xc3\xb3lar oficial, d\xc3\xb3lar hoy, cotizaci\xc3\xb3n del d\xc3\xb3lar" />\r\n\r\n    <script src="https://code.jquery.com/jquery-3.3.1.js"></script>\r\n    <script src="/shared/scripts/funciones.js" type="text/javascript"></script>\r\n    <script src="/scripts/jquery.timeago.js" type="text/javascript"></script>\r\n    <script src="/scripts/jquery.timeago.es.js" type="text/javascript"></script>\r\n    <link rel="stylesheet" type="text/css" media="all" href="//cdn.datatables.net/1.10.19/css/jquery.dataTables.min.css" /><link rel="stylesheet" type="text/css" media="all" href="https://cdn.datatables.net/fixedheader/3.1.5/css/fixedHeader.dataTables.min.css" /><link rel="stylesheet" type="text/css" media="all" href="https://cdn.datatables.net/responsive/2.2.3/css/responsive.dataTables.min.css" />  \r\n    <script type="text/javascript" src="//cdn.datatables.net/1.10.19/js/jquery.dataTables.min.js"></script>\r\n    <script type="text/javascript" src="https://cdn.datatables.net/fixedheader/3.1.5/js/dataTables.fixedHeader.min.js"></script>\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=1" /><meta name="apple-mobile-web-app-capable" content="yes" /><meta name="HandheldFriendly" content="True" /><meta name="apple-mobile-web-app-status-bar-style" content="black" /><link href="https://fonts.googleapis.com/css?family=Lato:400,700,400italic,700italic" rel="stylesheet" type="text/css" /><link rel="stylesheet" type="text/css" media="all" href="/shared/scripts/megamenu/css/color-theme.css" /><link rel="stylesheet" type="text/css" media="all" href="/shared/scripts/megamenu/css/webslidemenu.css?20190401" /><link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.7.2/css/all.css" integrity="sha384-fnmOCqbTlWIlj8LyTjo7mOUStjsKC4pOpQbqyi7RrhN7udi9RwhKkMHpvLbHG9Sr" crossorigin="anonymous" />\r\n    <script type="text/javascript" src="/shared/scripts/megamenu/js/webslidemenu.js"></script>\r\n    <link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png?v=2bb5zdzbXP" /><link rel="apple-touch-icon" sizes="60x60" href="/apple-touch-icon-60x60.png?v=2bb5zdzbXP" /><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png?v=2bb5zdzbXP" /><link rel="apple-touch-icon" sizes="76x76" href="/apple-touch-icon-76x76.png?v=2bb5zdzbXP" /><link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png?v=2bb5zdzbXP" /><link rel="apple-touch-icon" sizes="120x120" href="/apple-touch-icon-120x120.png?v=2bb5zdzbXP" /><link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png?v=2bb5zdzbXP" /><link rel="apple-touch-icon" sizes="152x152" href="/apple-touch-icon-152x152.png?v=2bb5zdzbXP" /><link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon-180x180.png?v=2bb5zdzbXP" /><link rel="icon" type="image/png" href="/favicon-32x32.png?v=2bb5zdzbXP" sizes="32x32" /><link rel="icon" type="image/png" href="/and ...

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
#             w[l] = w[l] || []; w[l].push({
#                 'gtm.start':
#                     new Date().getTime(), event: 'gtm.js'
#             }); var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                     'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-5FMGPWS');</script>
# <!-- End Google Tag Manager -->
# <title>
# 	Precio del dólar - InfoDolar.com.pe
# </title>
# <meta content="Precio del dólar hoy en Perú de cada banco y casa de cambio al instante. Tipo de cambio en Perú" name="Description"/>
# <meta content="dólar, dolar, precio dolar, precio dólar, precio dolar Peru, dólar paralelo, dólar oficial, dólar hoy, cotización del dólar" name="keywords"/>
# <script src="https://code.jquery.com/jquery-3.3.1.js"></script>
# <script src="/shared/scripts/funciones.js" type="text/javascript"></script>
# <script src="/scripts/jquery.timeago.js" type="text/javascript"></script>
# <script src="/scripts/jquery.timeago.es.js" type="text/javascript"></script>
# <link href="//cdn.datatables.net/1.10.19/css/jquery.dataTables.min.css" media="all" rel="stylesheet" type="text/css"/><link href="https://cdn.datatables.net/fixedheader/3.1.5/css/fixedHeader.dataTables.min.css" media="all" rel="stylesheet" type="text/css"/><link href="https://cdn.datatables.net/responsive/2.2.3/css/responsive.dataTables.min.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="//cdn.datatables.net/1.10.19/js/jquery.dataTables.min.js" type="text/javascript"></script>
# <script src="https://cdn.datatables.net/fixedheader/3.1.5/js/dataTables.fixedHeader.min.js" type="text/javascript"></script>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=1" name="viewport"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="True" name="HandheldFriendly"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><link href="https://fonts.googleapis.com/css?family=Lato:400,700,400italic,700italic" rel="stylesheet" type="text/css"/><link href="/shared/scripts/megamenu/css/color-theme.css" media="all" rel="stylesheet" type="text/css"/><link href="/shared/scripts/megamenu/css/webslidemenu.css?20190401" media="all" rel="stylesheet" type="text/css"/><link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.7.2/css/all.css" integrity="sha384-fnmOCqbTlWIlj8LyTjo7mOUStjsKC4pOpQbqyi7RrhN7udi9RwhKkMHpvLbHG9Sr" rel="stylesheet"/>
# <script src="/shared/scripts/megamenu/js/webslidemenu.js" type="text/javascript"></script>
# <link href="/apple-touch-icon-57x57.png?v=2bb5zdzbXP" rel="apple-touch-icon" sizes="57x57"/><link href="/apple-touch-icon-60x60.png?v=2bb5zdzbXP" rel="apple-touch-icon" sizes="60x60"/><link href="/apple-touch-icon-72x72.png?v=2bb5zdzbXP" rel="apple-touch-icon" sizes="72x72"/><link href="/apple-touch-icon-76x76.png?v=2bb5zdzbXP" rel="apple-touch-icon" sizes="76x76"/><link href="/apple-touch-icon-114x114.png?v=2bb5zdzbXP" rel="apple-touch-icon" sizes="114x114"/><link href="/apple-touch-icon-120x120.png?v=2bb5zdzbXP" rel="apple-touch-icon" sizes="120x120"/><link href="/apple-touch-icon-144x144.png?v=2bb5zdzbXP" rel="apple-touch-icon" sizes="144x144"/><link href="/apple-touch-icon-152x152.png?v=2bb5zdzbXP" rel="apple-touch-icon" sizes="152x152"/><link href="/apple-touch-icon-180x180.png?v=2bb5zdzbXP" rel="apple-touch-icon" sizes="180x180"/><link href="/favicon-32x32.png?v=2bb5zdzbXP" rel="icon" sizes="32x32" type="image/png"/><link href="/android-chrome-192x192.png?v=2bb5zdzbXP" rel="icon" sizes="192x192" type="image/png"/><link href="/favicon-96x96.png?v=2bb5zdzbXP" rel="icon" sizes="96x96" type="image/png"/><link href="/favicon-16x16.png?v=2bb5zdzbXP" rel="icon" sizes="16x16" type="image/png"/>
# <!--<link rel="manifest" href="/manifest.json?v=2bb5zdzbXP" />-->
# <link color="#2f8646" href="/safari-pinned-tab.svg?v=2bb5zdzbXP" rel="mask-icon"/><link href="/favicon.ico?v=2bb5zdzbXP" rel="shortcut icon"/><meta content="#da532c" name="msapplication-TileColor"/><meta content="/mstile-144x144.png?v=2bb5zdzbXP" name="msapplication-TileImage"/><meta content="#ffffff" name="theme-color"/><meta content="InfoDolar.com.pe" property="og:site_name"/><meta content="InfoDolar.com.pe" property="og:title"/><meta content="Tipo de cambio hoy en bancos y casas de cambio online" property="og:description"/><meta content="/shared/images/fotos/cotizacion-dolar.jpg" itemprop="image" property="og:image"/><meta content="website" property="og:type"/><meta content=" https://www.infodolar.com.pe/" property="og:url"/><meta content="1440432930" property="og:updated_time"/>
# <script type="text/javascript">
#         setTimeout(function () {
#             location = ''
#         }, 300000)
#     </script>
# <script async="" nonce="Ikswzqea3nV_ag0Jrsh6SQ" src="https://fundingchoicesmessages.google.com/i/pub-9939042165880640?ers=1"></script><script nonce="Ikswzqea3nV_ag0Jrsh6SQ">(function () { function signalGooglefcPresent() { if (!window.frames['googlefcPresent']) { if (document.body) { const iframe = document.createElement('iframe'); iframe.style = 'width: 0; height: 0; border: none; z-index: -1000; left: -1000px; top: -1000px;'; iframe.style.display = 'none'; iframe.name = 'googlefcPresent'; document.body.appendChild(iframe); } else { setTimeout(signalGooglefcPresent, 0); } } } signalGooglefcPresent(); })();</script>
# <link href="App_Themes/main/20211229/Styles.css" rel="stylesheet" type="text/css"/><link href="App_Themes/main/20211229/StylesButton.css" rel="stylesheet" type="text/css"/></head>
# <body>
# <form action="./" id="aspnetForm" method="post">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="hi70fLH8JFF/i7ZixSSOFxrk//wfxir29iZPQ3naKC1mveVrfTAHQM3R+7679q6w15RgLYi7pcqtnn+i7aFAsjUacvaVSGxeim0qfHymxgY="/>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="CA0B0334"/>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5FMGPWS" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <script async="" data-ad-client="ca-pub-9939042165880640" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <div class="wsmenucontainer clearfix">
# <div id="home">
# <div id="header">
# <a href="https://www.infodolar.com.pe/" id="logo"><img alt="precio del dólar" height="59" src="/shared/images/logos/infodolar.png" srcset="/shared/images/logos/infodolar.png 1x, /shared/images/logos/infodolar-2x.png 2x" width="170"/></a>
# <span id="bannerNews">
#         Recibe info sobre el <strong>precio del dólar hoy</strong> en Perú en tu email. <a href="https://infodolar.us1.list-manage.com/subscribe?u=873df675083bbfd932adefa5f&amp;id=ec9f8ded97" rel="nofollow" target="_blank"><strong>¡Suscríbete GRATIS ahora!</strong></a>
# </span>
# <div id="social">
# <span>Síguenos</span>
# <a href="https://www.instagram.com/infodolarpe/" rel="nofollow" target="_blank"><i class="fab fa-instagram fa-2x instagram"></i></a>
# <a href="https://infodolar.us1.list-manage.com/subscribe?u=873df675083bbfd932adefa5f&amp;id=ec9f8ded97" rel="nofollow" target="_blank" title="el dólar en tu email"><i class="far fa-envelope fa-2x newsletter"></i></a>
# </div>
# </div>
# <div class="wsmenucontent overlapblackbg"></div>
# <div class="wsmenuexpandermain slideRight">
# <a class="animated-arrow slideLeft" id="navToggle"><span></span></a>
# <a class="smallogo" href="/"><img alt="InfoDolar.com" height="35" src="/shared/images/logos/infodolar-mobile.png" srcset="/shared/images/logos/infodolar-mobile.png 1x, /shared/images/logos/infodolar-mobile-2x.png 2x" width="102"/></a>
# </div>
# <!--Main Menu HTML Code-->
# <nav class="wsmenu slideLeft clearfix id-grdt">
# <ul class="mobile-sub wsmenu-list">
# <li><a class="active" href="/"><i class="fa fa-home"></i><span class="hometext">  Home</span></a></li>
# <li><a href="#"><i class="fas fa-dollar-sign"></i>  Dólar <span class="arrow"></span></a>
# <ul class="wsmenu-submenu">
# <li><a href="/tipo-de-cambio-dolar-provincia-lima.aspx"><i class="fa fa-table fa-fw"></i>Tipo de cambio Dólar en Lima</a></li>
# <li><a href="/donde-comprar-dolares.aspx"><i class="fa fa-university fa-fw"></i>Dónde comprar dólares</a></li>
# </ul>
# </li>
# <li><a href="#"><i class="fas fa-euro-sign"></i>  Euro <span class="arrow"></span></a>
# <ul class="wsmenu-submenu">
# <li><a href="/tipo-de-cambio-euro.aspx"><i class="fa fa-table fa-fw"></i>Tipo de cambio Euro</a></li>
# <li><a href="/tipo-de-cambio-euro-provincia-lima.aspx"><i class="fa fa-table fa-fw"></i>Tipo de cambio Euro en Lima</a></li>
# <li><a href="/donde-comprar-euros.aspx"><i class="fa fa-university fa-fw"></i>Dónde comprar euros</a></li>
# </ul></li>
# </ul>
#
# <li><a href="#"><i class="far fa-money-bill-alt"></i>  Más monedas<span class="arrow"></span></a>
# <ul class="wsmenu-submenu">
# <li><a href="#"><i class="fa fa-angle-right"></i>Real</a>
# <ul class="wsmenu-submenu-sub">
# <li><a href="/tipo-de-cambio-real.aspx"><i class="fa fa-table fa-fw"></i>Tipo de cambio Real</a></li>
# <li><a href="/tipo-de-cambio-real-provincia-lima.aspx"><i class="fa fa-table fa-fw"></i>Tipo de cambio Real en Lima</a></li>
# <li><a href="/donde-comprar-reales.aspx"><i class="fa fa-university fa-fw"></i>Dónde comprar Reales</a></li>
# </ul>
# </li>
# <li><a href="#"><i class="fa fa-angle-right"></i>Peso colombiano</a>
# <ul class="wsmenu-submenu-sub">
# <li><a href="/tipo-de-cambio-peso-colombiano.aspx"><i class="fa fa fa-table fa-fw"></i>Tipo de cambio Peso Colombiano</a></li>
# <li><a href="/tipo-de-cambio-peso-colombiano-provincia-lima.aspx"><i class="fa fa-table fa-fw"></i>Tipo de cambio Peso Colombiano en Lima</a></li>
# <li><a href="/donde-comprar-pesos-colombianos.aspx"><i class="fa fa-university fa-fw"></i>Dónde comprar pesos colombianos</a></li>
# </ul>
# </li>
# <li><a href="#"><i class="fa fa-angle-right"></i>Stablecoins</a>
# <ul class="wsmenu-submenu-sub">
# <li><a href="/tipo-de-cambio-dai.aspx"><i class="fa fa fa-table fa-fw"></i>Tipo de cambio DAI</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a href="" rel="nofollow" target="_blank"><i class="far fa-envelope fa-fw"></i> Newsletter</a></li>
# <li><a href="/empresa/contacto/">Contacto</a></li>
#
# </nav>
# <!--Menu HTML Code-->
# <div id="content">
# <script>
#         jQuery(document).ready(function () {
#             jQuery("abbr.timeago").timeago();
#
#             $('#Dolar').DataTable({
#                 "order": [[2, 'asc']],
#                 "paging": false,
#                 "bInfo": false,
#                 "autoWidth": false,
#                 responsive: true,
#                 fixedHeader: {
#                     header: true,
#                     headerOffset: $('#header').css('display') == 'block' ? 0 : 50
#                 },
#                 "language": {
#                     "url": "//cdn.datatables.net/plug-ins/1.10.19/i18n/Spanish.json",
#                 },
#                 "columnDefs": [
#                     { "orderable": false, "targets": 5 },
#                     { "searchable": false, "targets": [1, 2, 3, 4, 5] },
#                     { "orderSequence": ["desc", "asc"], "targets": [1] }
#
#                 ]
#             }
#             );
#
#
#         });
#         </script>
# <div class="widerContent">
# <div class="centrado">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Infodolar Top Home -->
# <ins class="adsbygoogle ad adTop" data-ad-client="ca-pub-9939042165880640" data-ad-format="rectangle" data-ad-slot="3767699457" style="display:block"></ins>
# <script>
#                 (adsbygoogle = window.adsbygoogle || []).push({});
#             </script>
# </div>
# </div>
# <div id="widerContent">
# <div class="addthis_inline_share_toolbox"></div>
# <img alt="Dólar norteamericano" class="floatLeft flag" src="/shared/images/iconos/usa.png"/>
# <h1 class="superTitulo">Precio del dólar</h1>
# <table class="cotizaciones" id="DolarPromedio">
# <thead>
# <tr>
# <th class="dolar"></th>
# <th class="dolar">Compra</th>
# <th class="dolar">Venta</th>
# <th class="dolar">Variación</th>
# <th class="dolar">Spread</th>
# <th class="dolar"><i class="far fa-clock"></i></th>
# </tr>
# </thead>
# <tr>
# <td class="colNombre">
# <span class="nombre">Promedio InfoDolar</span>
# </td>
# <td class="colCompraVenta" data-order="3.7154090909090909090909090909">
#                                 S/3.715
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.026</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7496363636363636363636363636">
#                                 S/3.750
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.034</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.92 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.034
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-sunat.aspx"><img alt="Tipo de cambio SUNAT" src="/images/entidades/sunat.png"/></a>
# <span class="nombre"><a href="/tipo-de-cambio-sunat.aspx">Tipo de cambio SUNAT</a></span>
# </td>
# <td class="colCompraVenta" data-order="3.6980">
#                                 S/3.698
#                                 <span class="variacionCompraVenta"><span class="igual"> = S/0.000</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7070">
#                                 S/3.707
#                                 <span class="variacionCompraVenta"><span class="igual"> = S/0.000</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="igual"> = 0.00 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.009
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T09:10:00-05:00">lunes, 15 de abril de 2024 09:10 Perú</abbr>
# </td>
# </tr>
# </table>
# <div class="centrado">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Infodolar Middle Home -->
# <ins class="adsbygoogle ad adMiddle" data-ad-client="ca-pub-9939042165880640" data-ad-format="rectangle" data-ad-slot="6227649053" style="display:block"></ins>
# <script>
#                 (adsbygoogle = window.adsbygoogle || []).push({});
#             </script>
# </div>
# <br/><br/>
# <img alt="Dólar norteamericano" class="floatLeft flag" src="/shared/images/iconos/usa.png">
# <h2 class="superTitulo">Precio del Dólar hoy en bancos y casas de cambio</h2>
# <table class="cotizaciones" id="Dolar">
# <thead>
# <tr>
# <th class="dolar">Entidad</th>
# <th class="dolar">Compra</th>
# <th class="dolar">Venta</th>
# <th class="dolar">Variación</th>
# <th class="dolar">Spread</th>
# <th class="dolar"><i class="far fa-clock"></i></th>
# </tr>
# </thead>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-western-union.aspx"><img alt="Dólar Western Union" src="/images/entidades/western-union.png"/></a>
# <span class="nombre">Western Union
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7050">
#                                 S/3.705
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.011</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7350">
#                                 S/3.735
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.022</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.59 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.030
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-dollar-house.aspx"><img alt="Dólar Dollar House" src="/images/entidades/dollar-house-2.png"/></a>
# <span class="nombre">Dollar House
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7220">
#                                 S/3.722
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.022</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7370">
#                                 S/3.737
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.032</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.86 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.015
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-roblex.aspx"><img alt="Dólar Roblex" src="/images/entidades/roblex.png"/></a>
# <span class="nombre">Roblex
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7180">
#                                 S/3.718
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.028</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7380">
#                                 S/3.738
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.028</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.75 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.020
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-cambi.aspx"><img alt="Dólar Cambi" src="/images/entidades/cambi.png"/></a>
# <span class="nombre">Cambi
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7170">
#                                 S/3.717
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.024</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7390">
#                                 S/3.739
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.034</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.92 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.022
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-hirpower.aspx"><img alt="Dólar HIRPOWER" src="/images/entidades/hirpower.png"/></a>
# <span class="nombre">HIRPOWER
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7000">
#                                 S/3.700
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.010</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7400">
#                                 S/3.740
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.030</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.81 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.040
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-inka-money.aspx"><img alt="Dólar Inka Money" src="/images/entidades/inka-money.png"/></a>
# <span class="nombre">Inka Money
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7030">
#                                 S/3.703
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.014</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7420">
#                                 S/3.742
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.037</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 1.00 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.039
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-tucambista.aspx"><img alt="Dólar Tucambista" src="/images/entidades/tucambista.png"/></a>
# <span class="nombre">Tucambista
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7210">
#                                 S/3.721
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.031</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7470">
#                                 S/3.747
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.035</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.94 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.026
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-tkambio.aspx"><img alt="Dólar TKambio" src="/images/entidades/tkambio.png"/></a>
# <span class="nombre">TKambio
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7140">
#                                 S/3.714
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.028</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7490">
#                                 S/3.749
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.028</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.75 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.035
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T19:50:00-05:00">lunes, 15 de abril de 2024 19:50 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-instakash.aspx"><img alt="Dólar InstaKash" src="/images/entidades/instakash.png"/></a>
# <span class="nombre">InstaKash
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7120">
#                                 S/3.712
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.024</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7490">
#                                 S/3.749
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.035</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.94 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.037
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-kambista.aspx"><img alt="Dólar Kambista" src="/images/entidades/kambista.png"/></a>
# <span class="nombre">Kambista
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7130">
#                                 S/3.713
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.030</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7500">
#                                 S/3.750
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.038</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 1.02 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.037
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-rextie.aspx"><img alt="Dólar Rextie" src="/images/entidades/rextie.png"/></a>
# <span class="nombre">Rextie
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7130">
#                                 S/3.713
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.029</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7500">
#                                 S/3.750
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.031</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.83 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.037
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-acomo.aspx"><img alt="Dólar AComo" src="/images/entidades/acomo.png"/></a>
# <span class="nombre">AComo
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7170">
#                                 S/3.717
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.028</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7500">
#                                 S/3.750
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.035</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.94 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.033
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-cambio-mundial.aspx"><img alt="Dólar Cambio Mundial" src="/images/entidades/cambio-mundial.png"/></a>
# <span class="nombre">Cambio Mundial
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7300">
#                                 S/3.730
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.035</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7500">
#                                 S/3.750
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.035</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.94 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.020
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-peru-dolar.aspx"><img alt="Dólar Perú Dólar" src="/images/entidades/peru-dolar.png"/></a>
# <span class="nombre">Perú Dólar
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7100">
#                                 S/3.710
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.030</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7500">
#                                 S/3.750
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.020</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.54 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.040
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-cambiox.aspx"><img alt="Dólar CambioX" src="/images/entidades/cambiox.png"/></a>
# <span class="nombre">CambioX
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7200">
#                                 S/3.720
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.032</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7500">
#                                 S/3.750
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.032</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.86 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.030
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-cambio-sol.aspx"><img alt="Dólar Cambio Sol" src="/images/entidades/cambio-sol.png"/></a>
# <span class="nombre">Cambio Sol
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7150">
#                                 S/3.715
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.025</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7500">
#                                 S/3.750
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.030</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.81 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.035
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-diners-fx.aspx"><img alt="Dólar Diners FX" src="/images/entidades/diners-fx.png"/></a>
# <span class="nombre">Diners FX
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7200">
#                                 S/3.720
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.032</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7520">
#                                 S/3.752
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.036</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.97 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.032
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-cambix.aspx"><img alt="Dólar Cambix" src="/images/entidades/cambix.png"/></a>
# <span class="nombre">Cambix
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7080">
#                                 S/3.708
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.028</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7550">
#                                 S/3.755
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.035</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.94 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.047
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-cambiafx.aspx"><img alt="Dólar CambiaFX" src="/images/entidades/cambiafx.png"/></a>
# <span class="nombre">CambiaFX
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7190">
#                                 S/3.719
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.029</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7590">
#                                 S/3.759
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.044</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 1.18 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.040
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T19:50:00-05:00">lunes, 15 de abril de 2024 19:50 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-midpoint-fx.aspx"><img alt="Dólar MidPoint FX" src="/images/entidades/midpoint-fx.png"/></a>
# <span class="nombre">MidPoint FX
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7200">
#                                 S/3.720
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.045</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7600">
#                                 S/3.760
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.045</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 1.21 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.040
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-buenbit.aspx"><img alt="Dólar Buenbit" src="/images/entidades/buenbit.png"/></a>
# <span class="nombre">Buenbit
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7400">
#                                 S/3.740
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.032</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7660">
#                                 S/3.766
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.032</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.86 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.026
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-dolar-entidad-cambio-seguro.aspx"><img alt="Dólar Cambio Seguro" src="/images/entidades/cambio-seguro.png"/></a>
# <span class="nombre">Cambio Seguro
#
#                                 <span class="cambio-online"><span class="fas fa-stack fa-sm fa-fw icono-cambio-online" title="Cambio online"><i class="fas fa-dollar-sign fa-stack-1x fa-fw icono-dolar"></i><i class="fas fa-mobile-alt fa-stack-2x fa-fw icono-mobile"></i></span><span class="texto-cambio-online">Cambio online</span></span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7020">
#                                 S/3.702
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.012</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7740">
#                                 S/3.774
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.059</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 1.59 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.072
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# </table>
# </img></div>
# <div class="widerContent">
# <h2 class="superTitulo">Precio del dólar hoy en Perú</h2>
# <p>¿Quieres conocer <strong>cuánto está el dólar</strong> en Perú? En <strong>InfoDolar.com.pe</strong> puedes conocer el <strong><a href="/">precio del dólar</a></strong> de los principales bancos y casas de cambio de Perú (incluyendo las casas de cambio online). También puedes conocer el <a href="/tipo-de-cambio-euro.aspx"><strong>precio del euro</strong></a> y el <strong>tipo de cambio</strong> de otras monedas.</p>
# <h2 class="superTitulo"></h2>
# </div>
# <div class="widerContent">
# <p class="superTitulo">Otras cotizaciones</p>
# <ul class="listaMonedas" id="ctl00_PlaceHolderBottom_Monedas_BulletedListMonedas">
# <li><a href="/tipo-de-cambio-dai.aspx">DAI</a></li><li><a href="/tipo-de-cambio-dolar.aspx">Dólar</a></li><li><a href="/tipo-de-cambio-euro.aspx">Euro</a></li><li><a href="/tipo-de-cambio-peso-colombiano.aspx">Peso colombiano</a></li><li><a href="/tipo-de-cambio-real.aspx">Real</a></li><li><a href="/tipo-de-cambio-sunat.aspx">SUNAT</a></li>
# </ul>
# </div>
# </div><!-- content -->
# <div id="footer">
# <div id="topFooter">
# <div class="footerCol">
# <p><strong>El Dólar en otros países</strong></p>
# <p>Argentina - <a href="https://www.infodolar.com/" target="_blank">Dólar hoy</a> / <a href="https://www.infodolar.com/cotizacion-dolar-blue.aspx" target="_blank">Dólar blue</a></p>
# <p>Colombia - <a href="https://www.infodolar.com.co/" target="_blank">Dólar hoy</a></p>
# <p>Costa Rica - <a href="https://www.infodolar.co.cr/" target="_blank">Tipo de cambio del dólar</a></p>
# <p>España - <a href="https://www.infodolar.es/" target="_blank">Cambio Euro Dólar</a></p>
# <p>Estados Unidos - <a href="https://www.info-dollar.com/" target="_blank">Euro to dollar</a></p>
# <p>Guatemala - <a href="https://www.infodolar.com.gt/" target="_blank">Precio del Dólar</a></p>
# <p>México - <a href="https://www.infodolar.com.mx/" target="_blank">Precio del Dólar</a></p>
# <p>Nicaragua - <a href="https://ni.infodolar.com/" target="_blank">Tipo de cambio</a></p>
# <p>República Dominicana - <a href="https://www.infodolar.com.do/" target="_blank">Precio del Dólar</a></p>
# </div>
# <div class="footerColLast">
# <p><a href="/empresa/contacto/" title="Contacto con InfoDolar">Contacto</a></p>
# </div>
# <div class="clearer"></div>
# </div>
# <a href="/"><img alt="Precio del dólar" id="logoFooter" src="/shared/images/logos/infodolar-logo-small.gif"/></a>
# <p id="copyright">Copyright © 2024 InfoDolar.com.pe <br>
# </br></p>
# <p id="disclaimer">El <strong>precio del dólar</strong> y de otras monedas informado tienen un carácter orientativo, por lo que deben ser tomados únicamente a modo de referencia.
#     </p>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="https://ads.vidoomy.com/infodolar.com.pe_18049.js" type="text/javascript"></script>
# </div><!-- home end -->
# </div><!-- wsmenucontainer clearfix end -->
# <script data-cfasync="false" id="clever-core" type="text/javascript">
#              /* <![CDATA[ */
#              (function (document, window) {
#                  var a, c = document.createElement("script"), f = window.frameElement;
#
#                  c.id = "CleverCoreLoader73668";
#                  c.src = "https://scripts.cleverwebserver.com/35c76c2cf6a1f61aacd6e62b771c4cea.js";
#
#                  c.async = !0;
#                  c.type = "text/javascript";
#                  c.setAttribute("data-target", window.name || (f && f.getAttribute("id")));
#                  c.setAttribute("data-callback", "put-your-callback-function-here");
#                  c.setAttribute("data-callback-url-click", "put-your-click-macro-here");
#                  c.setAttribute("data-callback-url-view", "put-your-view-macro-here");
#
#                  try {
#                      a = parent.document.getElementsByTagName("script")[0] || document.getElementsByTagName("script")[0];
#                  } catch (e) {
#                      a = !1;
#                  }
#
#                  a || (a = document.getElementsByTagName("head")[0] || document.getElementsByTagName("body")[0]);
#                  a.parentNode.insertBefore(c, a);
#              })(document, window);
#             /* ]]> */
#      </script>
# </form>
# </body>
# </html>

# %%
table = soup.find("table", id="DolarPromedio")

# %%
table
# Out:
# <table class="cotizaciones" id="DolarPromedio">
# <thead>
# <tr>
# <th class="dolar"></th>
# <th class="dolar">Compra</th>
# <th class="dolar">Venta</th>
# <th class="dolar">Variación</th>
# <th class="dolar">Spread</th>
# <th class="dolar"><i class="far fa-clock"></i></th>
# </tr>
# </thead>
# <tr>
# <td class="colNombre">
# <span class="nombre">Promedio InfoDolar</span>
# </td>
# <td class="colCompraVenta" data-order="3.7154090909090909090909090909">
#                                 S/3.715
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.026</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7496363636363636363636363636">
#                                 S/3.750
#                                 <span class="variacionCompraVenta"><span class="alza"><i class="fa fa-arrow-up"></i> S/0.034</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="alza"><i class="fa fa-arrow-up"></i> 0.92 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.034
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T20:00:00-05:00">lunes, 15 de abril de 2024 20:00 Perú</abbr>
# </td>
# </tr>
# <tr>
# <td class="colNombre">
# <a href="/tipo-de-cambio-sunat.aspx"><img alt="Tipo de cambio SUNAT" src="/images/entidades/sunat.png"/></a>
# <span class="nombre"><a href="/tipo-de-cambio-sunat.aspx">Tipo de cambio SUNAT</a></span>
# </td>
# <td class="colCompraVenta" data-order="3.6980">
#                                 S/3.698
#                                 <span class="variacionCompraVenta"><span class="igual"> = S/0.000</span></span>
# </td>
# <td class="colCompraVenta" data-order="3.7070">
#                                 S/3.707
#                                 <span class="variacionCompraVenta"><span class="igual"> = S/0.000</span></span>
# </td>
# <td class="colVariacion">
# <span class="variacion"><span class="igual"> = 0.00 %</span></span>
# </td>
# <td class="colSpread">
#                                 S/0.009
#                             </td>
# <td class="colFecha">
# <abbr class="timeago date" title="2024-04-15T09:10:00-05:00">lunes, 15 de abril de 2024 09:10 Perú</abbr>
# </td>
# </tr>
# </table>

# %%
dolar_table = pd.read_html(str(table))[0]
dolar_table
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_26220\1185697896.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dolar_table = pd.read_html(str(table))[0]
#              Unnamed: 0              Compra               Venta Variación  \
# 0    Promedio InfoDolar    S/3.715  S/0.026    S/3.750  S/0.034    0.92 %
# 1  Tipo de cambio SUNAT  S/3.698  = S/0.000  S/3.707  = S/0.000  = 0.00 %
#
#     Spread                             Unnamed: 5
# 0  S/0.034  lunes, 15 de abril de 2024 20:00 Perú
# 1  S/0.009  lunes, 15 de abril de 2024 09:10 Perú

# %%
dolar_table["Compra"]
# Out:
# 0      S/3.715  S/0.026
# 1    S/3.698  = S/0.000
# Name: Compra, dtype: object

# %%
precio_dolar = dolar_table["Compra"][0]

# %%
precio_dolar
# Out:
# 'S/3.715  S/0.026'

# %%
precio_dolar = float(precio_dolar.split(" ")[0].replace("S/",""))

# %%
precio_dolar
# Out:
# 3.715

# %%
vendedor_data
# Out:
#    idvendedor            nombre sexo                            dirección
# 0           1    Fredy Saavedra    M              AV la merced - Colombia
# 1           2    Maria Cisneros    F               jr manco capac 118 SJM
# 2           3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú

# %%
ventas_data
# Out:
#    idEstudiante  idPrograma  idVendedor  montofinalventa
# 0      23423442           1           1            450.0
# 1      23423525           2           2            350.0
# 2      34534573           3           3            550.0
# 3      34534576           4           3            599.0
# 4      34534634           5           2            300.0
# 5      34634636           6           1            800.0
# 6      34636567           7           1            500.0
# 7      45645647           6           3            700.0
# 8      45646647           5           2            300.0
# 9      45647836           3           1            450.0
# 10     76565434           1           2            430.0
# 11     56756776           2           3            350.0
# 12     65756756           5           1            300.0

# %%
ventas_data_unificado = pd.merge(vendedor_data, ventas_data,
         left_on="idvendedor",
         right_on="idVendedor",
         how="left")

# %%
ventas_data_unificado.head()
# Out:
#    idvendedor          nombre sexo                dirección idEstudiante  \
# 0           1  Fredy Saavedra    M  AV la merced - Colombia     23423442
# 1           1  Fredy Saavedra    M  AV la merced - Colombia     34634636
# 2           1  Fredy Saavedra    M  AV la merced - Colombia     34636567
# 3           1  Fredy Saavedra    M  AV la merced - Colombia     45647836
# 4           1  Fredy Saavedra    M  AV la merced - Colombia     65756756
#
#    idPrograma  idVendedor  montofinalventa
# 0           1           1            450.0
# 1           6           1            800.0
# 2           7           1            500.0
# 3           3           1            450.0
# 4           5           1            300.0

# %%
ventas_data_unificado[["idvendedor","nombre","idEstudiante","idPrograma","montofinalventa"]]
ventas_data_unificado
# Out:
#     idvendedor            nombre sexo                            dirección  \
# 0            1    Fredy Saavedra    M              AV la merced - Colombia
# 1            1    Fredy Saavedra    M              AV la merced - Colombia
# 2            1    Fredy Saavedra    M              AV la merced - Colombia
# 3            1    Fredy Saavedra    M              AV la merced - Colombia
# 4            1    Fredy Saavedra    M              AV la merced - Colombia
# 5            2    Maria Cisneros    F               jr manco capac 118 SJM
# 6            2    Maria Cisneros    F               jr manco capac 118 SJM
# 7            2    Maria Cisneros    F               jr manco capac 118 SJM
# 8            2    Maria Cisneros    F               jr manco capac 118 SJM
# 9            3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú
# 10           3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú
# 11           3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú
# 12           3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú
#
#    idEstudiante  idPrograma  idVendedor  montofinalventa
# 0      23423442           1           1            450.0
# 1      34634636           6           1            800.0
# 2      34636567           7           1            500.0
# 3      45647836           3           1            450.0
# 4      65756756           5           1            300.0
# 5      23423525           2           2            350.0
# 6      34534634           5           2            300.0
# 7      45646647           5           2            300.0
# 8      76565434           1           2            430.0
# 9      34534573           3           3            550.0
# 10     34534576           4           3            599.0
# 11     45645647           6           3            700.0
# 12     56756776           2           3            350.0

# %%
ventas_data_unificado = ventas_data_unificado.rename(columns={'nombre':'nombreVendedor'})

# %%
ventas_data_unificado
# Out:
#     idvendedor    nombreVendedor sexo                            dirección  \
# 0            1    Fredy Saavedra    M              AV la merced - Colombia
# 1            1    Fredy Saavedra    M              AV la merced - Colombia
# 2            1    Fredy Saavedra    M              AV la merced - Colombia
# 3            1    Fredy Saavedra    M              AV la merced - Colombia
# 4            1    Fredy Saavedra    M              AV la merced - Colombia
# 5            2    Maria Cisneros    F               jr manco capac 118 SJM
# 6            2    Maria Cisneros    F               jr manco capac 118 SJM
# 7            2    Maria Cisneros    F               jr manco capac 118 SJM
# 8            2    Maria Cisneros    F               jr manco capac 118 SJM
# 9            3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú
# 10           3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú
# 11           3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú
# 12           3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú
#
#    idEstudiante  idPrograma  idVendedor  montofinalventa
# 0      23423442           1           1            450.0
# 1      34634636           6           1            800.0
# 2      34636567           7           1            500.0
# 3      45647836           3           1            450.0
# 4      65756756           5           1            300.0
# 5      23423525           2           2            350.0
# 6      34534634           5           2            300.0
# 7      45646647           5           2            300.0
# 8      76565434           1           2            430.0
# 9      34534573           3           3            550.0
# 10     34534576           4           3            599.0
# 11     45645647           6           3            700.0
# 12     56756776           2           3            350.0

# %%
df_matricula_cliente=pd.merge(matricula_data,programa_data,
                            left_on="codigo_programa",
                            right_on="codigo_programa",
                            how="inner"
                            )

# %%
df_matricula_cliente.rename(columns={"descripcion":"programa"}, inplace=True)

df_matricula_cliente=df_matricula_cliente[["dni_estudiante","programa","fecha_matricula","inversion"]]

# %%
df_matricula_cliente
# Out:
#   dni_estudiante                           programa fecha_matricula  inversion
# 0       23423442     Data Analyst Program I Edición      2023-01-01      600.0
# 1       23423525    Data Analyst Program II Edición      2023-01-04      700.0
# 2       34534573   Data Analyst Program III Edición      2023-01-10      550.0
# 3       34534576    Data Engineer Program I Edición      2023-01-11      800.0
# 4       34534634   Data Engineer Program II Edición      2023-01-20      450.0
# 5       34634636   Data Scientist Program I Edición      2023-03-02      850.0
# 6       34636567  Data Scientist Program II Edición      2023-03-02      650.0
# 7       45645647   Data Scientist Program I Edición      2023-03-12      850.0
# 8       45646647   Data Engineer Program II Edición      2023-03-25      450.0
# 9       65756756  Data Scientist Program II Edición      2023-02-23      650.0

# %%
df_cliente_unificado=pd.merge(df_matricula_cliente,cliente_data,
                            left_on="dni_estudiante",
                            right_on="dni_estudiante",
                            how="inner"
                            )

# %%
df_cliente_unificado.rename(columns={"dni_estudiante":"dniCliente","nombre":"nombreCliente","domicilio":"domicilioCliente"}, inplace=True)

# %%
df_cliente_unificado.head()
# Out:
#   dniCliente                          programa fecha_matricula  inversion  \
# 0   23423442    Data Analyst Program I Edición      2023-01-01      600.0
# 1   23423525   Data Analyst Program II Edición      2023-01-04      700.0
# 2   34534573  Data Analyst Program III Edición      2023-01-10      550.0
# 3   34534576   Data Engineer Program I Edición      2023-01-11      800.0
# 4   34534634  Data Engineer Program II Edición      2023-01-20      450.0
#
#                     nombreCliente  \
# 0        Kenyo Harold Cano Campos
# 1  Jeisser Augusto Asto Sifuentes
# 2      Christian Caballero Mueras
# 3          Elayne Palacios Vargas
# 4                  Esteban Vargas
#
#                                     domicilioCliente
# 0               Jr 28 De Julio 537 A Cercado - Surco
# 1                        Av Puente piedra 543 - Lima
# 2  Av Independencia Cda 06 Ex Casa Campesin - La ...
# 3                           av Perú 114 - Los olivos
# 4                          Jr. Ucayali N° 388  - SJL

# %%
df_cliente_ventas=pd.merge(df_cliente_unificado,ventas_data_unificado,
                            left_on="dniCliente",
                            right_on="idEstudiante",
                            how="inner"
                            )

# %%
df_cliente_ventas.head()
# Out:
#   dniCliente                          programa fecha_matricula  inversion  \
# 0   23423442    Data Analyst Program I Edición      2023-01-01      600.0
# 1   23423525   Data Analyst Program II Edición      2023-01-04      700.0
# 2   34534573  Data Analyst Program III Edición      2023-01-10      550.0
# 3   34534576   Data Engineer Program I Edición      2023-01-11      800.0
# 4   34534634  Data Engineer Program II Edición      2023-01-20      450.0
#
#                     nombreCliente  \
# 0        Kenyo Harold Cano Campos
# 1  Jeisser Augusto Asto Sifuentes
# 2      Christian Caballero Mueras
# 3          Elayne Palacios Vargas
# 4                  Esteban Vargas
#
#                                     domicilioCliente  idvendedor  \
# 0               Jr 28 De Julio 537 A Cercado - Surco           1
# 1                        Av Puente piedra 543 - Lima           2
# 2  Av Independencia Cda 06 Ex Casa Campesin - La ...           3
# 3                           av Perú 114 - Los olivos           3
# 4                          Jr. Ucayali N° 388  - SJL           2
#
#      nombreVendedor sexo                            dirección idEstudiante  \
# 0    Fredy Saavedra    M              AV la merced - Colombia     23423442
# 1    Maria Cisneros    F               jr manco capac 118 SJM     23423525
# 2  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú     34534573
# 3  Deisser Martinez    M  pasaje la cultura 234 Arequipa Perú     34534576
# 4    Maria Cisneros    F               jr manco capac 118 SJM     34534634
#
#    idPrograma  idVendedor  montofinalventa
# 0           1           1            450.0
# 1           2           2            350.0
# 2           3           3            550.0
# 3           4           3            599.0
# 4           5           2            300.0

# %%
df_cliente_ventas=df_cliente_ventas[["dniCliente",
                                          "fecha_matricula",
                                         "nombreCliente",
                                         "programa",
                                         "nombreVendedor",
                                         "inversion",
                                         "montofinalventa"]]

# %%
df_cliente_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   dniCliente       10 non-null     object
#  1   fecha_matricula  10 non-null     object
#  2   nombreCliente    10 non-null     object
#  3   programa         10 non-null     object
#  4   nombreVendedor   10 non-null     object
#  5   inversion        10 non-null     float64
#  6   montofinalventa  10 non-null     float64
# dtypes: float64(2), object(5)
# memory usage: 692.0+ bytes

# %%
df_mkt.head()
# Out:
#   idCampaña                    nombrePrograma  dniEstudiante plataforma  \
# 0   001DAP1    Data Analyst Program I Edición       23423442   Facebook
# 1   002DAP2   Data Analyst Program II Edición       23423525     Tiktok
# 2   003DAP3  Data Analyst Program III Edición       34534573  Instagram
# 3   001DEP1   Data Engineer Program I Edición       34534576  Instagram
# 4   001DEP2  Data Engineer Program II Edición       34534634     Tiktok
#
#   communityManager costoUSD
# 0    Flavia Avanto    0.972
# 1      Naomi Colan     2.34
# 2    Flavia Avanto    1.542
# 3    Flavia Avanto  1.6234s
# 4    Flavia Avanto   2.5246

# %%
df_mkt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   idCampaña         10 non-null     object
#  1   nombrePrograma    10 non-null     object
#  2   dniEstudiante     10 non-null     int64
#  3   plataforma        10 non-null     object
#  4   communityManager  10 non-null     object
#  5   costoUSD          10 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 612.0+ bytes

# %%
df_mkt["dniEstudiante"] = df_mkt["dniEstudiante"].astype(str)

# %%
df_ventas_mkdata=pd.merge(df_mkt,df_cliente_ventas,
                                       left_on="dniEstudiante",
                                       right_on="dniCliente",
                                       how="left")

# %%
df_ventas_datapath=df_ventas_mkdata[["fecha_matricula",
                                        "nombreCliente",
                                        "programa",
                                        "nombreVendedor",
                                        "inversion",
                                        "montofinalventa",
                                        "plataforma",
                                        "communityManager",
                                        "costoUSD"]]

# %%
df_ventas_datapath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fecha_matricula   10 non-null     object
#  1   nombreCliente     10 non-null     object
#  2   programa          10 non-null     object
#  3   nombreVendedor    10 non-null     object
#  4   inversion         10 non-null     float64
#  5   montofinalventa   10 non-null     float64
#  6   plataforma        10 non-null     object
#  7   communityManager  10 non-null     object
#  8   costoUSD          10 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 852.0+ bytes

# %%
df_ventas_datapath["costoUSD"] = pd.to_numeric(df_ventas_datapath["costoUSD"], errors="coerce")
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_26220\3147896875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ventas_datapath["costoUSD"] = pd.to_numeric(df_ventas_datapath["costoUSD"], errors="coerce")

# %%
df_ventas_datapath["costoSoles"] = df_ventas_datapath["costoUSD"] * precio_dolar
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_26220\2486429079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ventas_datapath["costoSoles"] = df_ventas_datapath["costoUSD"] * precio_dolar

# %%
df_ventas_datapath.head()
# Out:
#   fecha_matricula                   nombreCliente  \
# 0      2023-01-01        Kenyo Harold Cano Campos
# 1      2023-01-04  Jeisser Augusto Asto Sifuentes
# 2      2023-01-10      Christian Caballero Mueras
# 3      2023-01-11          Elayne Palacios Vargas
# 4      2023-01-20                  Esteban Vargas
#
#                            programa    nombreVendedor  inversion  \
# 0    Data Analyst Program I Edición    Fredy Saavedra      600.0
# 1   Data Analyst Program II Edición    Maria Cisneros      700.0
# 2  Data Analyst Program III Edición  Deisser Martinez      550.0
# 3   Data Engineer Program I Edición  Deisser Martinez      800.0
# 4  Data Engineer Program II Edición    Maria Cisneros      450.0
#
#    montofinalventa plataforma communityManager  costoUSD  costoSoles
# 0            450.0   Facebook    Flavia Avanto    0.9720    3.610980
# 1            350.0     Tiktok      Naomi Colan    2.3400    8.693100
# 2            550.0  Instagram    Flavia Avanto    1.5420    5.728530
# 3            599.0  Instagram    Flavia Avanto       NaN         NaN
# 4            300.0     Tiktok    Flavia Avanto    2.5246    9.378889

# %%
pip install google-cloud-bigquery
# Out:
# Requirement already satisfied: google-cloud-bigquery in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (3.20.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (2.18.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery) (2.29.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery) (2.7.0)
# Requirement already satisfied: packaging>=20.0.0 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery) (23.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery) (2.31.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (1.23.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (1.62.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (1.62.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery) (1.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (2024.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (15.0.2)
# Requirement already satisfied: numpy<2,>=1.16.6 in c:\users\usuario\appdata\local\programs\python\python312\lib\site-packages (from pyarrow) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.cloud import bigquery

ruta_conexion = "credenciales/datapath-bigquery.json"

client = bigquery.Client.from_service_account_json(ruta_conexion)

# %%
table_id = "dap12-datapath-418401.ds_ventas_datapath.ventas"

schema = []
table = bigquery.Table(table_id, schema=schema)

table = client.create_table(table)

# %%
job_config = bigquery.LoadJobConfig(
    schema = [
        bigquery.SchemaField("nombreCliente", "STRING"),
        bigquery.SchemaField("programa", "STRING"),
        bigquery.SchemaField("fecha_matricula", "DATE"),
        bigquery.SchemaField("nombreVendedor", "STRING"),
        bigquery.SchemaField("montofinalventa", "FLOAT"),
        bigquery.SchemaField("inversion", "FLOAT"),
        bigquery.SchemaField("plataforma", "STRING"),
        bigquery.SchemaField("communityManager", "STRING"),
        bigquery.SchemaField("costoUSD", "FLOAT"),
        bigquery.SchemaField("costoSoles", "FLOAT")
    ],

    write_disposition = "WRITE_TRUNCATE" # WRITE_APPEND
)

job = client.load_table_from_dataframe(
    df_ventas_datapath,
    table_id,
    job_config = job_config
)

# %%
job.result()
# Out:
# LoadJob<project=dap12-datapath-418401, location=US, id=9a2a5e91-34d9-4df6-b371-eb0fdf585986>
